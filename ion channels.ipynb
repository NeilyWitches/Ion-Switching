# %%
file_path_train = r"C:\Users\drumm\Documents\kaggle\liverpool-ion-switching\train.csv"
file_path_test = r"C:\Users\drumm\Documents\kaggle\liverpool-ion-switching\test.csv"
import pandas as pd
ion_data_train = pd.read_csv(file_path_train)
ion_data_test = pd.read_csv(file_path_test)

# %%
import matplotlib.pyplot as plot
# %matplotlib inline
import seaborn as sns

# %%
ion_data_train
# Out:
#              time  signal  open_channels
# 0          0.0001 -2.7600              0
# 1          0.0002 -2.8557              0
# 2          0.0003 -2.4074              0
# 3          0.0004 -3.1404              0
# 4          0.0005 -3.1525              0
# 5          0.0006 -2.6418              0
# 6          0.0007 -2.6993              0
# 7          0.0008 -2.5935              0
# 8          0.0009 -2.6682              0
# 9          0.0010 -2.7586              0
# 10         0.0011 -3.1136              0
# 11         0.0012 -2.6221              0
# 12         0.0013 -2.7316              0
# 13         0.0014 -2.9028              0
# 14         0.0015 -2.7736              0
# 15         0.0016 -2.9272              0
# 16         0.0017 -2.9240              0
# 17         0.0018 -2.7019              0
# 18         0.0019 -2.3167              0
# 19         0.0020 -2.9907              0
# 20         0.0021 -3.1911              0
# 21         0.0022 -3.0463              0
# ...

# %%
sns.scatterplot(x=ion_data['time'],y=ion_data['signal'])

# %%
sns.scatterplot(x=ion_data_test['signal'],y=preds_int_xg)

# %%
import numpy as np
#x = np.array(ion_data_train.signal)
x = ion_data_train.signal
y = ion_data_train.open_channels
#x_train = np.array(x_train)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(x.reshape(-1,1),y)
m = reg.coef_
b = reg.intercept_

# %%
i=0
for i in range(len())
# Out:
# [array([0.14138733]),
#  array([0.01356488]),
#  array([0.00677671]),
#  array([0.27894375]),
#  array([0.16335281]),
#  array([0.1951163]),
#  array([0.08503274]),
#  array([0.05877663]),
#  array([0.01458951]),
#  array([0.31685501]),
#  array([-0.04336606]),
#  array([0.15938237]),
#  array([-0.02645968]),
#  array([-0.16292744]),
#  array([-0.11355313]),
#  array([0.27426888]),
#  array([0.21106209]),
#  array([0.30552006]),
#  array([-0.15005554]),
#  array([-0.01525281]),
#  array([0.22034778]),
#  array([0.29258412]),
#  array([0.38524899]),
#  array([-0.08915416]),
#  array([0.07158449]),
#  array([0.38275145]),
#  array([0.29130333]),
#  array([0.18275671]),
#  array([0.11724451]),
#  array([0.10962383]),
#  array([0.13171739]),
#  array([0.21266307]),
#  array([0.10302778]),
#  array([0.11686027]),
#  array([0.30654468]),
#  array([0.12870754]),
#  array([0.11090462]),
#  array([0.40516521]),
#  array([0.09585538]),
#  array([-0.01743014]),
#  array([0.33094366]),
# ...

# %%
sns.scatterplot(x=ion_data_train['signal'],y=ion_data_train['open_channels'])

# %%
x_test = ion_data_test.signal

# %%
x_test = np.array(x_test)

# %%
x_test = list(x_test)
# Out:
# [-2.6498,
#  -2.8494,
#  -2.86,
#  -2.435,
#  -2.6155,
#  -2.5659,
#  -2.7378,
#  -2.7788,
#  -2.8478,
#  -2.3758,
#  -2.9383,
#  -2.6217,
#  -2.9119,
#  -3.125,
#  -3.0479,
#  -2.4423,
#  -2.541,
#  -2.3935,
#  -3.1049,
#  -2.8944,
#  -2.5265,
#  -2.4137,
#  -2.269,
#  -3.0098,
#  -2.7588,
#  -2.2729,
#  -2.4157,
#  -2.5852,
#  -2.6875,
#  -2.6994,
#  -2.6649,
#  -2.5385,
#  -2.7097,
#  -2.6881,
#  -2.3919,
#  -2.6696,
#  -2.6974,
#  -2.2379,
#  -2.7209,
#  -2.8978,
#  -2.3538,
#  -2.8486,
#  -2.5827,
#  -2.3506,
#  -3.0839,
#  -2.3742,
#  -2.698,
#  -2.5823,
#  -2.9104,
#  -2.8207,
#  -2.7233,
#  -2.6044,
#  -2.0506,
#  -2.3329,
#  -2.8276,
#  -2.7935,
#  -2.5107,
#  -3.1014,
#  -2.4466,
#  -2.6467,
#  -2.8521,
#  -2.8893,
#  -2.355,
#  -2.5932,
#  -2.6788,
#  -2.5513,
#  -2.4507,
#  -2.7577,
#  -2.8386,
#  -2.4621,
#  -2.6324,
#  -2.3506,
#  -2.7388,
#  -2.6101,
#  -2.5474,
#  -3.1463,
#  -2.3216,
#  -2.653,
#  -2.7681,
#  -2.559,
#  -2.1425,
#  -2.4774,
#  -2.8367,
#  -2.5448,
# ...

# %%
x = ion_data_train.signal

# %%
i=0
predictions = []
for i in range(len(x_test)):
    predictions.append(m*x_test[i] + b)

# %%
predictions2 = []
for i in range(len(x)):
    predictions2.append(m*x[i] + b)

# %%
x_test = ion_data_test

# %%
sns.scatterplot(x=ion_data_test['signal'],y=predictions)

# %%
predictions2

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predictions2,y)
# Out:
# 1.1211187009214068

# %%
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(x,y)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor()
rf_model.fit(x.reshape(-1,1),y)
# Out:
# C:\Users\drumm\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
x_valid = np.array(x_valid)

# %%
mean_absolute_error(rf_predictions_2,y_valid)
# Out:
# 0.05599407999999998

# %%
x = ion_data_train.drop(['open_channels'],axis=1)

# %%
rf_predictions_2_test = rf_model.predict(x_test)

# %%
rf_predictions_1_test = rf_model.predict(x_test.reshape(-1,1))

# %%
rf_predictions_1_test
# Out:
# array([0.        , 0.00755042, 0.        , ..., 0.        , 0.        ,
#        0.        ])

# %%
sns.scatterplot(x=x_test['signal'],y=preds_int)

# %%
file_path_sample = r"C:\Users\drumm\Documents\kaggle\liverpool-ion-switching\sample_submission.csv"
sample = pd.read_csv(file_path_sample)
sample
# Out:
#              time  open_channels
# 0        500.0001              0
# 1        500.0002              0
# 2        500.0003              0
# 3        500.0004              0
# 4        500.0005              0
# 5        500.0006              0
# 6        500.0007              0
# 7        500.0008              0
# 8        500.0009              0
# 9        500.0010              0
# 10       500.0011              0
# 11       500.0012              0
# 12       500.0013              0
# 13       500.0014              0
# 14       500.0015              0
# 15       500.0016              0
# 16       500.0017              0
# 17       500.0018              0
# 18       500.0019              0
# 19       500.0020              0
# 20       500.0021              0
# 21       500.0022              0
# 22       500.0023              0
# 23       500.0024              0
# 24       500.0025              0
# 25       500.0026              0
# 26       500.0027              0
# ...

# %%
rf_predictions_2_test.dtype
# Out:
# dtype('float64')

# %%
i=0
preds_list = []
for i in range(len(predictions)):
    preds_list.append(predictions[i][0])

# %%
preds_list
# Out:
# [0.14138732571684387,
#  0.013564879592314671,
#  0.006776713615761709,
#  0.2789437456945436,
#  0.1633528061881433,
#  0.1951162998142788,
#  0.08503274025111951,
#  0.058776626568225465,
#  0.014589508418964448,
#  0.31685501228057644,
#  -0.043366059588399786,
#  0.15938236948487616,
#  -0.02645968394868281,
#  -0.16292743579806723,
#  -0.11355313421389268,
#  0.2742688766729551,
#  0.2110620859290122,
#  0.3055200558857658,
#  -0.1500555361632825,
#  -0.01525280615720348,
#  0.22034778467052352,
#  0.2925841169493155,
#  0.3852489864594326,
#  -0.08915416027930068,
#  0.07158448690134467,
#  0.3827514536944745,
#  0.2913033309160036,
#  0.18275671459281884,
#  0.11724450898891425,
#  0.10962383209070858,
#  0.1317173911653391,
#  0.21266306847065208,
#  0.1030277840191518,
#  0.11686027317892078,
#  0.30654468471241536,
#  0.12870754398705597,
#  0.1109046181240203,
#  0.40516520927743294,
#  0.09585538223260537,
#  -0.01743014241383367,
#  0.33094365864700737,
# ...

# %%
i=0
preds_rounded_rf_1 = []
for i in range(len(rf_predictions_1_test)):
    preds_rounded_rf_1.append(round(rf_predictions_1_test[i]))

# %%
i=0
preds_int_rf_1 = []
for i in range(len(preds_rounded_rf_1)):
    preds_int_rf_1.append(int(preds_rounded_rf_1[i]))

# %%
sample.describe()
# Out:
#                time  open_channels
# count  2.000000e+06      2000000.0
# mean   6.000001e+02            0.0
# std    5.773504e+01            0.0
# min    5.000001e+02            0.0
# 25%    5.500001e+02            0.0
# 50%    6.000000e+02            0.0
# 75%    6.500000e+02            0.0
# max    7.000000e+02            0.0

# %%
submission.describe()
# Out:
#                time  open_channels
# count  2.000000e+06   2.000000e+06
# mean   6.000001e+02   4.412805e+00
# std    5.773504e+01   2.113819e+00
# min    5.000001e+02   2.000000e+00
# 25%    5.500001e+02   2.000000e+00
# 50%    6.000000e+02   4.000000e+00
# 75%    6.500000e+02   6.000000e+00
# max    7.000000e+02   1.000000e+01

# %%
output = pd.DataFrame({'time': sample.time,
                      'open_channels': preds_int_rf_1})
output.to_csv('submission.csv', index=False, float_format='%.4f')

# %%
file_path_submission = r"C:\Users\drumm\Documents\kaggle\liverpool-ion-switching\submission.csv"
submission = pd.read_csv(file_path_submission)
submission.dtypes
# Out:
# time             float64
# open_channels      int64
# dtype: object

# %%
x = ion_data_train.drop('open_channels',axis=1)

# %%
from xgboost import XGBRegressor
xg_model = XGBRegressor(n_estimators=1000,learning_rate=0.05,n_jobs=4)
xg_model.fit(x,y)
# Out:
# [22:49:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:49:06] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.05, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=4, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
preds_xg = xg_model.predict(ion_data_test)

# %%
x = np.array(x)
