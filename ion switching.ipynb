# %%
file1 = r"C:\Users\drumm\Documents\kaggle\liverpool-ion-switching\sample_submission.csv"
file2 = r"C:\Users\drumm\Documents\kaggle\liverpool-ion-switching\train.csv"
file3 = r"C:\Users\drumm\Documents\kaggle\liverpool-ion-switching\test.csv"
file4 = r"C:\Users\drumm\Documents\kaggle\liverpool-ion-switching\submission.csv"

# %%
import pandas as pd

# %%
sample = pd.read_csv(file1)
train = pd.read_csv(file2)
test = pd.read_csv(file3)

# %%
submission = pd.read_csv(file4)

# %%
from sklearn.model_selection import train_test_split

# %%
y = train.open_channels

# %%
X = train.drop(['open_channels'],axis=1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,y)

# %%
predictions = forest_model.predict(X_valid)

# %%
mean_absolute_error(y_valid,predictions)
# Out:
# 0.05576

# %%
mean_absolute_error(predictions2,y_valid)
# Out:
# 0.12327715598788261

# %%
predictions2 = xg_model.predict(test)

# %%
output = pd.DataFrame({'time': test.time,
                      'open_channels': predictions2_rounded})
output.to_csv('submission.csv', index=False)

# %%
predictions2_rounded = []
for i in range(len(predictions2)):
    predictions2_rounded.append(round(predictions2[i]))

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
a = reg.coef_[0]
b = reg.coef_[1]
c = reg.intercept_
print(a,b,c)
# Out:
# -0.0057821330241275525 0.848333412359762 2.9955776793475106

# %%
preds
# Out:
# [427.17769018865704,
#  427.1789291357499,
#  427.1790752597012,
#  427.1767026865072,
#  427.17783119485927,
#  427.17762923440256,
#  427.1787080164106,
#  427.1790299172058,
#  427.17951371772574,
#  427.17686938427954,
#  427.1802066674469,
#  427.1784608774727,
#  427.1802236858175,
#  427.1815406917062,
#  427.1811797225913,
#  427.1777628961731,
#  427.17841842604383,
#  427.177650394764,
#  427.18184863753856,
#  427.1807163318782,
#  427.1786739184799,
#  427.178106527216,
#  427.1773546859087,
#  427.1817229233942,
#  427.18035644134636,
#  427.17763173625116,
#  427.17854225818826,
#  427.17960716307704,
#  427.1802835086267,
#  427.1804371493509,
#  427.18032249910283,
#  427.1796764708298,
#  427.1807512053448,
#  427.18071114461264,
#  427.1790833101521,
#  427.1807738418342,
#  427.1810194184735,
#  427.1784473616902,
#  427.18132496528204,
#  427.18243265795525,
#  427.1793720109314,
#  427.18231784369294,
#  427.18086520786306,
#  427.1796080081294,
# ...

# %%
x1_test = test.time

# %%
x2_test = test.signal

# %%
preds = []
for i in range(len(x1_test)):
    preds.append(b*x1_test[i] + a*x2_test[i] + c)

# %%
preds_df = pd.DataFrame(preds)

# %%
preds_df
# Out:
#                 0
# 0       -2.143403
# 1       -2.312731
# 2       -2.321724
# 3       -1.961183
# 4       -2.114308
# 5       -2.072231
# 6       -2.218060
# 7       -2.252842
# 8       -2.311378
# 9       -1.910965
# 10      -2.388153
# 11      -2.119571
# 12      -2.365758
# 13      -2.546539
# 14      -2.481133
# 15      -1.967383
# 16      -2.051114
# 17      -1.925985
# 18      -2.529490
# 19      -2.350917
# 20      -2.038815
# 21      -1.943124
# 22      -1.820371
# 23      -2.448817
# 24      -2.235886
# 25      -1.823681
# 26      -1.944823
# 27      -2.088617
# 28      -2.175402
# 29      -2.185497
# ...           ...
# 1999970 -3.392026
# 1999971 -3.540231
# 1999972 -3.070849
# 1999973 -3.784467
# 1999974 -3.370227
# 1999975 -3.523775
# 1999976 -3.294556
# 1999977 -3.225927
# 1999978 -3.297951
# 1999979 -3.658663
# 1999980 -3.448871
# 1999981 -3.425796
# 1999982 -3.463124
# 1999983 -3.648231
# 1999984 -3.272674
# 1999985 -3.377953
# 1999986 -3.144916
# 1999987 -3.606410
# ...
